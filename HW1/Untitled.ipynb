# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_theme()

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
# Out:
# /home/nikita/ML_fall_2023/ml_env/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/nikita/ML_fall_2023/ml_env/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/nikita/ML_fall_2023/ml_env/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
dots['coherence'].value_counts()
# Out:
# coherence
# 0.0     174
# 3.2     170
# 6.4     156
# 12.8    142
# 25.6    116
# 51.2     90
# Name: count, dtype: int64

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots,kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", style="choice"
)

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots()
x, y = dots[(dots['align'] == 'dots') & (dots['choice'] == 'T1')]['time'], dots[(dots['align'] == 'dots') & (dots['choice'] == 'T1')]['firing_rate']
ax.plot(x, y)

# %%
dots[(dots['align'] == 'dots') & (dots['choice'] == 'T1')][['time', 'firing_rate']]
# Out:
#      time  firing_rate
# 0     -80    33.189967
# 1     -80    31.691726
# 2     -80    34.279840
# 3     -80    32.631874
# 4     -80    35.060487
# ..    ...          ...
# 189   660    56.961320
# 190   680    52.674048
# 191   680    57.079948
# 192   700    52.680682
# 193   720    51.299586
#
# [194 rows x 2 columns]

# %%
import seaborn as sns
sns.set_theme()
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
sns.displot(data[data['17_group']!=0], x="rating", hue="blended", kind = 'kde')
